# %%
import datetime

# %%
from datetime import time,date,datetime
x=datetime.now()
print(x)
print(x.year)
print(x.month)
print(x.hour)
y=datetime(2025,12,31,15,10,59)
print(y)
print(x.date())
print(x.time())
# Out:
# 2025-12-04 13:30:38.304493
# 2025
# 12
# 13
# 2025-12-31 15:10:59
# 2025-12-04
# 13:30:38.304493

# %%
from datetime import time,date,datetime
d=int(input("Enter your birth date :"))
m=int(input("Enter your birth month :"))
y=int(input("Enter your birth year :"))
my=datetime(y,m,d)
a=datetime.now()
print(f"Number of days : {a-my}")
# Out:
# Enter your birth date :19
# Enter your birth month :01
# Enter your birth year :2007
# Number of days : 6894 days, 13:30:45.013598

# %%
# Types of Errors : 
# NameError
# keyError
# SyntexError
# TypeError
# ValueError
# IndexError
# ImportError
# IndentationError
# AttributeError
# ZeroDivisionError

# %%
print("hello")
print("bye")
a=10
b=0
print(a/b)
print("namaste")
# Out:
# hello
# bye
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-4-21722cc14ba8> in <module>
#       3 a=10
#       4 b=0
# ----> 5 print(a/b)
#       6 print("namaste")
#
# ZeroDivisionError: division by zero

# %%
print("hello")
 print("bye")
a=10
# Out:
#   File "<ipython-input-6-e5023922f952>", line 2
#     print("bye")
#     ^
# IndentationError: unexpected indent

# %%
a=10
print(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-5ec4c601e99c> in <module>
#       1 a=10
# ----> 2 print(X)
#
# NameError: name 'X' is not defined

# %%
l=[1,2,3]
l[29]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-e9703114ec58> in <module>
#       1 l=[1,2,3]
# ----> 2 l[29]
#
# IndexError: list index out of range

# %%
print("Hello"
# Out:
#   File "<ipython-input-9-73b2b6fc1c24>", line 1
#     print("Hello"
#                  ^
# SyntaxError: unexpected EOF while parsing

# %%
print("Hello)
# Out:
#   File "<ipython-input-10-e8dd6fae58d9>", line 1
#     print("Hello)
#                  ^
# SyntaxError: EOL while scanning string literal

# %%
a=10
if a>3
    print("hello")
# Out:
#   File "<ipython-input-11-029659320701>", line 2
#     if a>3
#           ^
# SyntaxError: invalid syntax

# %%
a="hello"
b=10
a+b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-86b20d792bfd> in <module>
#       1 a="hello"
#       2 b=10
# ----> 3 a+b
#
# TypeError: can only concatenate str (not "int") to str

# %%
a="helo"
b=int(a)
print(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-65e697e7aa68> in <module>
#       1 a="helo"
# ----> 2 b=int(a)
#       3 print(b)
#
# ValueError: invalid literal for int() with base 10: 'helo'

# %%
l=[1,2,3]
l.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-75e5d8703574> in <module>
#       1 l=[1,2,3]
# ----> 2 l.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
t=(1,2,3)
t.append(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-2de9d0c0b85a> in <module>
#       1 t=(1,2,3)
# ----> 2 t.append(5)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
import os3
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-8463aa564cba> in <module>
# ----> 1 import os3
#
# ModuleNotFoundError: No module named 'os3'

# %%
import os
os2.mkdir("xyz")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-fbf377e96345> in <module>
#       1 import os
# ----> 2 os2.mkdir("xyz")
#
# NameError: name 'os2' is not defined

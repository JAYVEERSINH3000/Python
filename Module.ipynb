# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\LJENG\\Desktop\\T3_PYTHON'

# %%
os.chdir(r"C:\\Users\\LJENG\\Desktop\\B4")

# %%
# get current working directory path
os.getcwd()
# Out:
# 'C:\\Users\\LJENG\\Desktop\\B4'

# %%
# create directory
os.mkdir("T3")

# %%
# create file
# %%writefile 1.txt
Hii
# Out:
# Writing 1.txt

# %%
# rename the file
os.rename("1.txt","demo.txt")

# %%
# delete file
# If we want to delete file in our current working directory than we only give name of file
# If we want t delete file in other folder than we have to give path
os.remove(os.getcwd()+"\\demo.txt")

# %%
# delete directory
os.rmdir(os.getcwd()+"\\T3")

# %%
os.chdir(r"C:\\Users\\LJENG\\Desktop\\T3_PYTHON")
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'file2.ipynb',
#  'mbox-short.txt',
#  'Module.ipynb',
#  'word.txt']

# %%
# %%writefile mod.py
a=10
c=20
def add(x,y):
    return x+y
def sub(x,y):
    return x-y
# Out:
# Overwriting mod.py

# %%
import mod
print(mod.a)
print(mod.c)
print(mod.add(2,3))
print(mod.sub(10,3))
# Out:
# 10
# 20
# 5
# 7

# %%
import mod as m
print(m.c)
print(m.add(1,2))
# Out:
# 20
# 3

# %%
from mod import add,c
print(c)
print(mod.add(5,4))
# print(a) # it gives error
# Out:
# 20
# 9

# %%
from mod import *
print(mod.a)
print(mod.c)
print(mod.add(20,30))
print(mod.sub(20,33))
# Out:
# 10
# 20
# 50
# -13

# %%
# %%writefile x.py
def length(n):
    return len(n)
def reverse(n):
    return n[::-1]
# Out:
# Writing x.py

# %%
import x
t=input("Enter string : ")
print(x.length(t))
print(x.reverse(t))
# Out:
# Enter string : Jayveer
# 7
# reevyaJ

# %%
class err(Exception):
    pass
class SQ:
    def __init__(self,l):
        self.l=l
    def shift(self):
        print("shift method :")
        try:
            if len(l)==0:
                raise Exception("List is empty")
        except Exception as e:
            print(e)
        else:
            d=l.pop(0)
            print(f"removed ele. is {d}")
            print(f"Updated list is {l}")
    def unshift(self):
        print("Unshift method :")
        n=int(input("Enter number to insert : "))
        self.l=l
        l.insert(0,n)
        print(f"inserted ele. is {n}")
        print(f"Updated list is {l}")
    def push(self):
        print("Push method :")
        n=int(input("Enter number to insert : "))
        self.l=l
        l.append(n)
        print(f"Updated list is {l}")
    def pop(self):
        print("Pop method :")
        d=l.pop()
        print(f"removed ele. is {d}")
        print(f"Updated list is {l}")
    def remove(self):
        print("Remove method :")
        m=max(l)
        ind=l.index(m)
        rem=l.pop(ind)
        print(f"removed ele. is {rem}")
        print(f"Updated list is {l}")
l=[]
while True:
    n1=input("Enter number or enter 'e' to exit: ")
    if n1=="e":
        break
    else:
        num=int(n1)
        l.append(num)
ob=SQ(l)
ob.shift()
ob.unshift()
ob.push()
ob.pop()
ob.remove()

# %%
class WordPlay:
    def __init__(self,l):
        self.l=l
    def words_with_length(self):
        length=int(input("Enter length : "))
        newl=[]
        for i in l:
            if len(i)==length:
                newl.append(i)
        print(f"{length} length words are :")
        print(newl)
        
    def starts_with(self):
        chara=input("Enter first character : ")
        newl=[]
        for i in l:
            if i[0]==chara:
                newl.append(i)
        print(f"First character '{chara}'  words are :")
        print(newl)
    def ends_with(self):
        chara=input("Enter last character : ")
        newl=[]
        for i in l:
            if i[-1]==chara:
                newl.append(i)
        print(f"Last character '{chara}'  words are :")
        print(newl)
    def palindromes(self):
        newl=[]
        for i in l:
            revl=i[::-1]
            if i==revl:
                newl.append(i)
        print("Palindromes :")
        print(newl)
    def only(self):
        p=input("Enter charcters that are in word: ")
        w=set(p)
        for i in l:
            z=set(i)
            if w.intersection(z)==w:
                print(i)
    def avoids(self):
        p=input("Enter charcters that are not in word: ")
        w=set(p)
        for i in l:
            z=set(i)
            if w.intersection(z)==set():
                print(i,end=",")
l=["apple","banana","find","dictionary","set","tuple","list","malayalam","nayan","grind","apricot"]
ob=WordPlay(l)
ob.words_with_length()
ob.starts_with()
ob.ends_with()
ob.palindromes()
ob.only()
ob.avoids()
# Out:
# Enter length : 5
# 5 length words are :
# ['apple', 'tuple', 'nayan', 'grind']
# Enter first character : a
# First character 'a'  words are :
# ['apple', 'apricot']
# Enter last character : e
# Last character 'e'  words are :
# ['apple', 'tuple']
# Palindromes :
# ['malayalam', 'nayan']
# Enter charcters that are in word: ban
# banana
# Enter charcters that are not in word: amkd
# set,tuple,list,
